# %% [markdown]
# # 6.26 감성분석 실습

# %%
import pandas as pd
reviews = pd.read_csv("./reviewData.csv", header=None,
                         names = ["name", "score", "review"], encoding = 'cp949')

# %%
reviews = reviews.drop_duplicates()

# %%
reviews = reviews[['score', 'review']]

# %%
reviews.groupby(['score'])

# %% [markdown]
# # PMI

# %% [markdown]
# ###  positive review : 7 ~ 9

# %%
positive = reviews[(reviews['score'] > 7) & (reviews["score"] < 10)]

# %% [markdown]
# ###  negative review : 5

# %%
negative = reviews[reviews['score'] < 4]

# %%
posN = len(positive)
negN = len(negative)
N = len(reviews) # hits(N)

# P(Y=neg) = hits(Y=neg)/hits(N)
# P(Y=Pos) = hits(Y=pos)/hits(N)
positive.count(), negative.count()
# Out:
# (score     1566
#  review    1566
#  dtype: int64, score     1552
#  review    1552
#  dtype: int64)

# %%
from collections import Counter, defaultdict
# counter는 value가 정렬 되어있음
from konlpy.tag import Komoran

ma = Komoran()

# %%
posDTM = defaultdict(Counter)
for i, review in positive.iterrows():
#     print(i, review)
    for pos in ma.pos(review['review']): # tuple(형태소, 품사)
        if len(pos[0]) > 1:
            posDTM[i][pos] += 1
            
negDTM = defaultdict(Counter)
for i, review in negative.iterrows():
    for pos in ma.pos(review['review']): # tuple(형태소, 품사)
        if len(pos[0]) > 1:
            negDTM[i][pos] += 1

# %%
negDTM
# Out:
# defaultdict(collections.Counter,
#             {15: Counter({('무료', 'NNP'): 1,
#                       ('주차', 'NNP'): 1,
#                       ('파킹', 'NNP'): 1,
#                       ('스토리', 'NNP'): 1}),
#              17: Counter({('마당을 나온 암탉', 'NNP'): 1,
#                       ('당시', 'NNG'): 1,
#                       ('다시', 'MAG'): 1,
#                       ('생각해보면', 'NNP'): 1,
#                       ('애국', 'NNG'): 1,
#                       ('마케팅', 'NNP'): 2,
#                       ('일반', 'NNG'): 1,
#                       ('홍보', 'NNG'): 1,
#                       ('그리고', 'MAJ'): 1,
#                       ('배우', 'NNG'): 1,
#                       ('때문', 'NNB'): 1,
#                       ('내용', 'NNG'): 1,
#                       ('기대', 'NNG'): 1}),
#              18: Counter({('솔직히', 'MAG'): 1,
#                       ('너무', 'MAG'): 1,
#                       ('재미없', 'VA'): 1,
#                       ('악질', 'NNG'): 1,
#                       ('경찰', 'NNG'): 1,
#                       ('오히러', 'NA'): 1,
#                       ('...', 'SE'): 1}),
#              26: Counter({('개연', 'NNG'): 1,
#                       ('너무', 'MAG'): 1,
#                       ('웃음', 'NNG'): 1,
#                       ('포인트', 'NNP'): 1,
#                       ('진지', 'XR'): 1,
#                       ('포인트', 'NNG'): 1}),
#              40: Counter({('별점', 'NNG'): 1,
#                       ('...', 'SE'): 2,
#                       ('토이', 'NNP'): 1,
#                       ('스토리', 'NNP'): 1,
#                       ('추억', 'NNG'): 1,
#                       ('생각', 'NNG'): 1,
#                       ('면서', 'EC'): 1,
#                       ('는데', 'EC'): 1,
#                       ('정말', 'MAG'): 1,
#                       ('다정', 'XR'): 1,
#                       ('어서', 'EC'): 1,
#                       ('놀라', 'VV'): 1,
#                       ('ㅋㅋㅋ', 'NA'): 1}),
#              51: Counter({('영화', 'NNG'): 1,
#                       ('수상', 'NNG'): 1,
#                       ('는지', 'EC'): 1,
#                       ('모르', 'VV'): 1}),
#              62: Counter({('기분', 'NNG'): 1, ('더럽', 'VA'): 1, ('어요', 'EC'): 1}),
#              80: Counter({('학교 3', 'NNP'): 1,
#                       ('학년', 'NNG'): 1,
#                       ('정도', 'NNG'): 1,
#                       ('좋아하', 'VV'): 1,
#                       ('내용', 'NNG'): 1,
#                       ('너무', 'MAG'): 1,
#                       ('유치', 'XR'): 1,
#                       ('클리셰', 'NNP'): 1,
#                       ('투성이', 'XSN'): 1,
#                       ('진부', 'XR'): 1,
#                       ('순정만화', 'NNP'): 1,
#                       ('이상', 'NNP'): 1,
#                       ('이하', 'NNG'): 1,
#                       ('아니', 'VCN'): 1}),
#              95: Counter({('어린이', 'NNG'): 1, ('아요', 'EC'): 1}),
#              99: Counter({('동생', 'NNG'): 1,
#                       ('이랑', 'NNP'): 1,
#                       ('다가', 'EC'): 2,
#                       ('서로', 'MAG'): 1,
#                       ('유치', 'XR'): 1,
#                       ('재미없', 'VA'): 1,
#                       ('다고', 'EC'): 1,
#                       ('투덜거리', 'VV'): 1,
#                       ('영화', 'NNG'): 2,
#                       ('솔직히', 'MAG'): 1,
#                       ('평하', 'VV'): 1,
#                       ('영화', 'NNP'): 1,
#                       ('해바라기', 'NNP'): 1,
#                       ('생각', 'NNG'): 1,
#                       ('실망', 'NNP'): 1,
#                       ('하고', 'JKB'): 1,
#                       ('김래원', 'NNP'): 1,
#                       ('해바라기', 'NNG'): 1}),
#              108: Counter({('거르', 'VV'): 1,
#                       ('아니', 'VCN'): 1,
#                       ('고식', 'NNG'): 1,
#                       ('김어준쩌리', 'NA'): 1,
#                       ('영상', 'NNP'): 1}),
#              119: Counter({('답답', 'XR'): 1,
#                       ('역겹', 'VA'): 1,
#                       ('자기', 'NNP'): 1,
#                       ('ㄴ다면', 'EC'): 1,
#                       ('추천', 'NNG'): 1,
#                       ('ㄴ다', 'EC'): 1}),
#              136: Counter({('아니', 'MAG'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('마무리', 'NNG'): 1,
#                       ('어야지', 'EC'): 1,
#                       ('갑자기', 'MAG'): 1,
#                       ('노래', 'NNG'): 1,
#                       ('부르', 'VV'): 1,
#                       ('어쩌', 'VV'): 1,
#                       ('씌2벌', 'NA'): 1,
#                       ('라라', 'NNP'): 1,
#                       ('랜드', 'NNP'): 1}),
#              139: Counter({('알바', 'NNP'): 1,
#                       ('ㄴ지', 'EC'): 2,
#                       ('뽕짝', 'NNG'): 1,
#                       ('좋아하', 'VV'): 1,
#                       ('...', 'SE'): 1}),
#              152: Counter({('내용', 'NNG'): 1,
#                       ('뻔히', 'MAG'): 1,
#                       ('예상', 'NNG'): 1,
#                       ('빨갱이', 'NNP'): 1,
#                       ('영화', 'NNP'): 1}),
#              153: Counter({('노무현', 'NNP'): 1,
#                       ('살아생전', 'NNG'): 1,
#                       ('뇌물', 'NNG'): 1,
#                       ('하나', 'NR'): 1,
#                       ('피아제', 'NNP'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('관람', 'NNG'): 1,
#                       ('베스트', 'NNP'): 1,
#                       ('후기', 'NNG'): 1,
#                       ('추첨', 'NNP'): 1,
#                       ('으로', 'JKB'): 1,
#                       ('경품', 'NNG'): 1,
#                       ('내걸', 'VV'): 1,
#                       ('어벤져스', 'NNP'): 1,
#                       ('간다', 'NNP'): 1}),
#              158: Counter({('완전', 'NNG'): 1,
#                       ('년대', 'NNB'): 2,
#                       ('영화', 'NNG'): 2,
#                       ('ㄴ데', 'EC'): 1,
#                       ('여기', 'NP'): 1,
#                       ('반응', 'NNG'): 1,
#                       ('신기', 'XR'): 1,
#                       ('네요', 'EF'): 1,
#                       ('어떻', 'VA'): 1,
#                       ('이런', 'MM'): 1,
#                       ('2019', 'SN'): 1,
#                       ('개봉', 'NNG'): 1,
#                       ('시대', 'NNG'): 1,
#                       ('역행', 'NNG'): 1,
#                       ('느낌', 'NNG'): 1,
#                       ('에요', 'EF'): 1}),
#              182: Counter({('젠장', 'IC'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('필요', 'NNG'): 1,
#                       ('ㄴ가', 'EF'): 1}),
#              185: Counter({('영혼', 'NNG'): 1,
#                       ('보내기', 'NNG'): 1,
#                       ('페미들', 'NA'): 1,
#                       ('화력', 'NNP'): 1,
#                       ('떨어지', 'VV'): 1,
#                       ('페미팔이가', 'NA'): 1,
#                       ('너무', 'MAG'): 1,
#                       ('어서', 'EC'): 1,
#                       ('선택', 'NNG'): 1,
#                       ('감수성', 'NNP'): 1,
#                       ('요한', 'NNP'): 1,
#                       ('페미가', 'NA'): 1,
#                       ('경우', 'NNG'): 1,
#                       ('햄스워드는', 'NA'): 1,
#                       ('페미영화', 'NA'): 1,
#                       ('전문', 'NNG'): 1,
#                       ('배우', 'NNP'): 1,
#                       ('고스트버스터즈', 'NNP'): 1,
#                       ('그렇', 'VA'): 1}),
#              198: Counter({('역겹', 'VA'): 2,
#                       ('동물', 'NNG'): 1,
#                       ('색스', 'NNP'): 1,
#                       ('..', 'SE'): 1,
#                       ('수간', 'NNP'): 1,
#                       ('...', 'SE'): 1,
#                       ('내내', 'MAG'): 1}),
#              210: Counter({('처음', 'NNG'): 1,
#                       ('으로', 'JKB'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('보다', 'JKB'): 1,
#                       ('핸드폰', 'NNG'): 1,
#                       ('여기', 'VV'): 2,
#                       ('못하', 'VX'): 1,
#                       ('여주', 'NNP'): 2,
#                       ('그런', 'MM'): 1,
#                       ('한테', 'JKB'): 1,
#                       ('한눈', 'NNG'): 1,
#                       ('반하', 'VV'): 1,
#                       ('깡패', 'NNG'): 1,
#                       ('갑자기', 'MAG'): 1,
#                       ('그만두', 'VV'): 1}),
#              241: Counter({('목격자', 'NNP'): 1,
#                       ('넘어서', 'VV'): 1,
#                       ('ㄴ다', 'EC'): 1,
#                       ('절대', 'NNG'): 1,
#                       ('보지', 'NNP'): 1,
#                       ('마라', 'NNP'): 1,
#                       ('중간', 'NNG'): 1,
#                       ('나오', 'VV'): 1}),
#              253: Counter({('기분', 'NNG'): 1,
#                       ('나쁜 영화', 'NNP'): 1,
#                       ('모텔', 'NNP'): 1,
#                       ('에서', 'JKB'): 1,
#                       ('화영', 'NNP'): 1,
#                       ('엎드려뻣쳐', 'NA'): 1,
#                       ('기억', 'NNG'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('알리', 'VV'): 1,
#                       ('은지', 'EC'): 1,
#                       ('모르', 'VV'): 1}),
#              286: Counter({('영화', 'NNG'): 1,
#                       ('점점', 'MAG'): 1,
#                       ('으로', 'JKB'): 1,
#                       ('간다', 'NNP'): 1}),
#              294: Counter({('전라도', 'NNP'): 1,
#                       ('욕보이', 'VV'): 1,
#                       ('아서', 'EC'): 1,
#                       ('내내', 'MAG'): 1,
#                       ('불편', 'NNG'): 1,
#                       ('습니다', 'EF'): 1,
#                       ('지역감정', 'NNG'): 1,
#                       ('조장', 'NNG'): 1,
#                       ('맙시다.', 'NA'): 1}),
#              296: Counter({('스필버그의', 'NA'): 1, ('...', 'SE'): 1}),
#              300: Counter({('초적', 'NNP'): 1,
#                       ('본능', 'NNP'): 1,
#                       ('고픈', 'ETM'): 1}),
#              312: Counter({('로튼', 'NNP'): 1,
#                       ('토마토', 'NNP'): 1,
#                       ('엑스맨', 'NNP'): 1,
#                       ('23', 'SN'): 1,
#                       ('블랙', 'NNP'): 1,
#                       ('33', 'SN'): 1,
#                       ('...', 'SE'): 1,
#                       ('와우', 'NNP'): 1}),
#              314: Counter({('알바', 'NNP'): 1,
#                       ('때문', 'NNB'): 1,
#                       ('아깝', 'VA'): 1,
#                       ('시간', 'NNG'): 1,
#                       ('날리', 'VV'): 1,
#                       ('세상', 'NNG'): 1,
#                       ('이렇', 'VA'): 1,
#                       ('재미없', 'VA'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('처음', 'NNG'): 1,
#                       ('더러', 'JKB'): 1}),
#              324: Counter({('진짜', 'MAG'): 1, ('아깝', 'VA'): 1}),
#              326: Counter({('오늘', 'NNG'): 1,
#                       ('김래원', 'NNP'): 1,
#                       ('나오', 'VV'): 1,
#                       ('ㄴ다', 'EC'): 1,
#                       ('아서', 'EC'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('는데', 'EC'): 1,
#                       ('재미없', 'VA'): 1}),
#              329: Counter({('관람객', 'NNG'): 1,
#                       ('으로', 'JKB'): 1,
#                       ('보내', 'VV'): 1,
#                       ('쇼잉', 'NNP'): 1}),
#              335: Counter({('어휴', 'IC'): 1,
#                       ('진짜', 'MAG'): 1,
#                       ('네이버', 'NNP'): 1,
#                       ('평점', 'NNG'): 2,
#                       ('보고', 'JKB'): 1,
#                       ('역시', 'MAJ'): 1,
#                       ('평론가', 'NNG'): 1,
#                       ('괜히', 'MAG'): 1,
#                       ('쓰레기', 'NNG'): 1,
#                       ('아니', 'VCN'): 1,
#                       ('해도', 'NNP'): 2,
#                       ('너무', 'MAG'): 1,
#                       ('ㄴ다', 'EC'): 1,
#                       ('영화', 'NNP'): 2,
#                       ('한국', 'NNP'): 1,
#                       ('관객', 'NNP'): 1,
#                       ('수준', 'NNG'): 1,
#                       ('얼마나', 'MAG'): 1,
#                       ('올라가', 'VV'): 1,
#                       ('는데', 'EC'): 1,
#                       ('이리', 'MAG'): 1,
#                       ('저급', 'NNG'): 1,
#                       ('개연', 'NNG'): 1,
#                       ('성제', 'NNP'): 1,
#                       ('진부', 'XR'): 1,
#                       ('플롯', 'NNP'): 1,
#                       ('한마디', 'NNG'): 1,
#                       ('최악', 'NNG'): 1,
#                       ('올해', 'NNG'): 1,
#                       ('보다', 'JKB'): 1,
#                       ('시계', 'NNG'): 1,
#                       ('몇번봤는지ㅜ', 'NA'): 1}),
#              350: Counter({('거르', 'VV'): 2,
#                       ('ㄹ걸', 'EF'): 1,
#                       ('실수', 'NNP'): 1,
#                       ('병맛', 'NNP'): 1,
#                       ('데스티네이션', 'NNP'): 1,
#                       ('아니', 'VCN'): 1,
#                       ('잔인', 'NNG'): 1,
#                       ('ㄹ래', 'EC'): 1,
#                       ('기만', 'NNG'): 1,
#                       ('진심', 'NNP'): 1,
#                       ('짜증', 'NNP'): 1,
#                       ('알라딘,맨인블랙,롱머시기', 'NA'): 1,
#                       ('실패', 'NNG'): 1}),
#              353: Counter({('식상', 'XR'): 1,
#                       ('전개', 'NNG'): 1,
#                       ('...', 'SE'): 1,
#                       ('그리고', 'MAJ'): 1,
#                       ('원진', 'NNP'): 1,
#                       ('어색', 'XR'): 1}),
#              371: Counter({('삼류', 'NNG'): 2,
#                       ('of', 'SL'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('ㄴ듯', 'EC'): 1,
#                       ('...', 'SE'): 1,
#                       ('최악', 'NNG'): 1}),
#              376: Counter({('고급', 'NNG'): 1,
#                       ('소고기', 'NNG'): 1,
#                       ('가지', 'VV'): 1,
#                       ('국밥', 'NNP'): 1,
#                       ('만들', 'VV'): 1}),
#              378: Counter({('불쾌', 'XR'): 1,
#                       ('풀어내', 'VV'): 1,
#                       ('계층', 'NNP'): 1,
#                       ('간의', 'NNP'): 1,
#                       ('차이', 'NNP'): 1,
#                       ('봉준호', 'NNP'): 1,
#                       ('감독', 'NNG'): 1,
#                       ('사상', 'NNG'): 1,
#                       ('담아내', 'VV'): 1}),
#              419: Counter({('배우', 'NNG'): 1,
#                       ('ㄴ다고', 'EC'): 1,
#                       ('아니', 'VCN'): 1,
#                       ('구나', 'EF'): 1}),
#              424: Counter({('안봄안봄안봄ㅋㅋㅋㅋ', 'NA'): 1}),
#              426: Counter({('노이즈', 'NNP'): 1,
#                       ('마켓팅.돈', 'NA'): 1,
#                       ('아깝', 'VA'): 1}),
#              433: Counter({('전라도', 'NNP'): 1,
#                       ('사투리', 'NNG'): 1,
#                       ('영화', 'NNP'): 2,
#                       ('...', 'SE'): 1,
#                       ('아직', 'MAG'): 1,
#                       ('이런', 'MM'): 1,
#                       ('쓰레기', 'NNG'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('만들', 'VV'): 1,
#                       ('한국', 'NNP'): 1,
#                       ('현실', 'NNG'): 1,
#                       ('..', 'SE'): 1,
#                       ('나오', 'VV'): 1,
#                       ('ㄴ다', 'EC'): 1}),
#              453: Counter({('웬만', 'XR'): 1,
#                       ('크리스 헴스워스', 'NNP'): 1,
#                       ('평점', 'NNG'): 1,
#                       ('은데', 'EC'): 1,
#                       ('...', 'SE'): 1,
#                       ('정말', 'NNP'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('보다', 'JKB'): 1,
#                       ('시계', 'NNG'): 1,
#                       ('는지', 'EC'): 1,
#                       ('정말', 'MAG'): 1,
#                       ('재미없', 'VA'): 1,
#                       ('어요', 'EC'): 1}),
#              454: Counter({('평점', 'NNG'): 1,
#                       ('조절', 'NNG'): 1,
#                       ('ㅂ니다', 'EC'): 1,
#                       ('적당', 'XR'): 1,
#                       ('개연', 'NNG'): 1}),
#              479: Counter({('조별', 'NNG'): 1,
#                       ('제로', 'NNP'): 1,
#                       ('제출', 'NNG'): 1,
#                       ('나오', 'VV'): 1,
#                       ('선배', 'NNG'): 1,
#                       ('하자?ㅋㅋ', 'NA'): 1}),
#              497: Counter({('당했네....ㅋㅋ', 'NA'): 1}),
#              514: Counter({('정확히', 'MAG'): 1,
#                       ('20', 'SN'): 1,
#                       ('크레딧', 'NNG'): 1,
#                       ('올라오', 'VV'): 1,
#                       ('일어나', 'VV'): 1}),
#              526: Counter({('시리즈', 'NNP'): 2,
#                       ('사람', 'NNG'): 1,
#                       ('으로', 'JKB'): 2,
#                       ('얼탱이가', 'NA'): 1,
#                       ('공포', 'NNP'): 1,
#                       ('영화', 'NNP'): 1,
#                       ('아니', 'VCN'): 1,
#                       ('로봇', 'NNP'): 1,
#                       ('인공지능', 'NNP'): 1,
#                       ('시대', 'NNG'): 1,
#                       ('관하', 'VV'): 1,
#                       ('sf', 'SL'): 1,
#                       ('영화로', 'NNP'): 1,
#                       ('처키', 'NNP'): 1,
#                       ('모랑', 'NNP'): 1,
#                       ('성우', 'NNP'): 1,
#                       ('달라지', 'VV'): 1,
#                       ('거르', 'VV'): 1,
#                       ('어야', 'EC'): 1,
#                       ('터미네이터', 'NNP'): 1,
#                       ('마냥', 'MAG'): 1,
#                       ('오래', 'MAG'): 1,
#                       ('우려먹', 'VV'): 1,
#                       ('어서', 'EC'): 1,
#                       ('이것', 'NP'): 1}),
#              539: Counter({('내내', 'MAG'): 1,
#                       ('알라딘', 'NNP'): 1,
#                       ('ㄹ걸', 'EC'): 1,
#                       ('후회', 'NNG'): 1,
#                       ('...', 'SE'): 2,
#                       ('엔딩크레딧', 'NNP'): 1,
#                       ('영상', 'NNP'): 1,
#                       ('소름', 'NNG'): 1,
#                       ('끼치', 'VV'): 1,
#                       ('유치', 'XR'): 1,
#                       ('호평', 'NNG'): 1,
#                       ('댓글', 'NNP'): 3,
#                       ('알바', 'NNP'): 1,
#                       ('ㄴ가', 'EF'): 1,
#                       ('귀하', 'VA'): 1,
#                       ('시간', 'NNP'): 1,
#                       ('날림', 'NNG'): 1,
#                       ('홧김', 'NNG'): 1,
#                       ('영화', 'NNG'): 2,
#                       ('최고', 'NNG'): 1,
#                       ('충동', 'NNG'): 1,
#                       ('부모', 'NNG'): 1,
#                       ('죽이', 'VV'): 1,
#                       ('원수', 'NNP'): 1,
#                       ('다면', 'EC'): 1,
#                       ('추천', 'NNG'): 1,
#                       ('바람', 'NNP'): 1}),
#              549: Counter({('전라도', 'NNP'): 1,
#                       ('깡패', 'NNG'): 1,
#                       ('새끼', 'NNP'): 1,
#                       ('미화', 'NNG'): 1,
#                       ('영화', 'NNP'): 1}),
#              580: Counter({('이건', 'NNP'): 1,
#                       ('아니', 'VCN'): 1,
#                       ('11', 'SN'): 1,
#                       ('마음', 'NNG'): 1}),
#              581: Counter({('습니다', 'EC'): 1, ('어요', 'EF'): 1}),
#              610: Counter({('ㅅㅂ..', 'NA'): 1,
#                       ('개독', 'NNP'): 1,
#                       ('몰려오', 'VV'): 1,
#                       ('ㄴ다', 'EC'): 1}),
#              613: Counter({('진짜', 'MAG'): 1,
#                       ('점수', 'NNG'): 1,
#                       ('ㅂ니다', 'EC'): 1,
#                       ('근데알바가너무많아서..ㅎ;;(양해좀)저는', 'NA'): 1,
#                       ('웹툰', 'NNP'): 2,
#                       ('너무', 'MAG'): 1,
#                       ('재미있', 'VA'): 1,
#                       ('는데', 'EC'): 1,
#                       ('워낙', 'MAG'): 1,
#                       ('명작', 'NNG'): 1,
#                       ('많이', 'MAG'): 1,
#                       ('나오', 'VV'): 1,
#                       ('그런지', 'NNP'): 1,
#                       ('영화로', 'NNP'): 1,
#                       ('표현', 'NNG'): 1,
#                       ('힘들', 'VA'): 1,
#                       ('부분', 'NNG'): 1,
#                       ('네요', 'EF'): 1,
#                       ('영화', 'NNP'): 1,
#                       ('나름', 'NNB'): 1,
#                       ('재밌', 'VA'): 2,
#                       ('습니다', 'EF'): 1,
#                       ('근데', 'MAJ'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('보고', 'JKB'): 1,
#                       ('!!', 'NNP'): 1,
#                       ('꼭웹툰보십시오..갓띵작', 'NA'): 1}),
#              623: Counter({('그것', 'NP'): 1,
#                       ('거시기', 'NP'): 1,
#                       ('몸매', 'NNP'): 2,
#                       ('대충', 'MAG'): 1,
#                       ('남자들', 'NNP'): 1,
#                       ('선호', 'NNG'): 1,
#                       ('내용', 'NNG'): 1,
#                       ('스릴', 'NNG'): 1,
#                       ('아주', 'MAG'): 1,
#                       ('아우', 'NNG'): 1,
#                       ('감상', 'NNP'): 1}),
#              625: Counter({('비우', 'VV'): 1,
#                       ('사람', 'NNG'): 1,
#                       ('습니다', 'EF'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('소리', 'NNG'): 1,
#                       ('집주인', 'NNG'): 1,
#                       ('미친놈', 'NNG'): 1,
#                       ('인줄', 'NNG'): 1,
#                       ('에요', 'EF'): 1}),
#              630: Counter({('이것', 'NP'): 1,
#                       ('번역', 'NNG'): 1,
#                       ('센스', 'NNG'): 1,
#                       ('어도', 'EC'): 1,
#                       ('평점', 'NNG'): 1,
#                       ('구만', 'EC'): 1}),
#              631: Counter({('이거', 'NP'): 1,
#                       ('까지', 'JX'): 1,
#                       ('지켜보', 'VV'): 1,
#                       ('어휴', 'IC'): 1}),
#              634: Counter({('이런', 'MM'): 1,
#                       ('토이', 'NNP'): 1,
#                       ('스토리', 'NNP'): 1,
#                       ('기대', 'NNG'): 1,
#                       ('한적', 'NNP'): 1}),
#              638: Counter({('이건', 'NNP'): 1,
#                       ('아니', 'VCN'): 1,
#                       ('...', 'SE'): 1,
#                       ('추억', 'NNP'): 1,
#                       ('돌리', 'VV'): 1}),
#              641: Counter({('잊어버리', 'VV'): 1,
#                       ('만들', 'VV'): 1,
#                       ('개망작ㅋㅋ와..감독이바뀐줄알았네우리나라는', 'NA'): 1,
#                       ('손꼽히는몇감독빼고는', 'NA'): 1,
#                       ('확실히', 'MAG'): 1,
#                       ('전부', 'MAG'): 1,
#                       ('어야', 'EC'): 1,
#                       ('ㅂ니다', 'EF'): 1}),
#              645: Counter({('아깝', 'VA'): 2, ('시간', 'NNG'): 1}),
#              652: Counter({('토이', 'NNP'): 1,
#                       ('스토리', 'NNP'): 1,
#                       ('에서', 'JKB'): 1,
#                       ('완벽', 'NNG'): 1,
#                       ('끝나', 'VV'): 1,
#                       ('어야', 'EC'): 1,
#                       ('...', 'SE'): 1}),
#              655: Counter({('덕분', 'NNG'): 1,
#                       ('원전', 'NNG'): 1,
#                       ('무능', 'NNG'): 1,
#                       ('재앙', 'NNG'): 1}),
#              656: Counter({('중간', 'NNG'): 1,
#                       ('타석', 'NNG'): 1,
#                       ('바꾸', 'VV'): 1,
#                       ('갈라지', 'VV'): 1,
#                       ('경우', 'NNG'): 1,
#                       ('조각', 'NNP'): 1,
#                       ('으면', 'EC'): 1,
#                       ('아웃', 'NNG'): 1,
#                       ('ㅂ니다', 'EC'): 1}),
#              665: Counter({('영화', 'NNP'): 1,
#                       ('그만', 'MAG'): 1,
#                       ('만들', 'VV'): 1,
#                       ('어라', 'EC'): 1,
#                       ('...', 'SE'): 1}),
#              669: Counter({('더보', 'NNP'): 1,
#                       ('겨우', 'MAG'): 1,
#                       ('극복', 'NNG'): 1,
#                       ('나니', 'NNP'): 1,
#                       ('인형', 'NNP'): 1,
#                       ('더 보이', 'NNP'): 1}),
#              670: Counter({('악마', 'NNP'): 1,
#                       ('잡아가', 'VV'): 1,
#                       ('하내', 'NNP'): 1,
#                       ('무섭', 'VA'): 1,
#                       ('라도', 'EC'): 1,
#                       ('던가', 'EC'): 1,
#                       ('화가', 'NNG'): 1,
#                       ('ㄴ다', 'EC'): 1}),
#              671: Counter({('역시', 'MAJ'): 1,
#                       ('페미', 'NA'): 1,
#                       ('영화', 'NNG'): 1}),
#              679: Counter({('인생', 'NNG'): 1,
#                       ('하나', 'NR'): 1,
#                       ('므로', 'EC'): 1,
#                       ('현재', 'NNG'): 1,
#                       ('즐기', 'VV'): 2,
#                       ('라는', 'ETM'): 1,
#                       ('명언', 'NNP'): 1,
#                       ('지만', 'EC'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('시간', 'NNG'): 1}),
#              682: Counter({('잔인', 'XR'): 1,
#                       ('하나', 'NR'): 1,
#                       ('무서움', 'NNG'): 1,
#                       ('...', 'SE'): 1}),
#              685: Counter({('겁나', 'VV'): 1,
#                       ('재미없', 'VA'): 1,
#                       ('진짜', 'NNG'): 1,
#                       ('..', 'SE'): 1,
#                       ('하디', 'NNP'): 1,
#                       ('뻔하', 'VA'): 1,
#                       ('신파', 'NNG'): 1,
#                       ('연속', 'NNP'): 1}),
#              696: Counter({('제발', 'MAG'): 1,
#                       ('도망치', 'VV'): 1,
#                       ('어요', 'EC'): 1,
#                       ('진짜', 'NNG'): 1}),
#              707: Counter({('싸구려', 'NNG'): 1,
#                       ('영화', 'NNP'): 1,
#                       ('이제', 'MAG'): 1,
#                       ('그만', 'MAG'): 1,
#                       ('...', 'SE'): 1,
#                       ('인간', 'NNG'): 1,
#                       ('충무로', 'NNP'): 1,
#                       ('벌레', 'NNG'): 1}),
#              711: Counter({('사람', 'NNG'): 1,
#                       ('마다', 'JX'): 1,
#                       ('다르', 'VA'): 1,
#                       ('별로', 'MAG'): 1}),
#              717: Counter({('각색', 'NNP'): 1,
#                       ('..', 'SE'): 1,
#                       ('이렇', 'VA'): 1,
#                       ('없었나요?...ㅜㅜ', 'NA'): 1}),
#              720: Counter({('예고편', 'NNP'): 1,
#                       ('한편', 'NNG'): 1,
#                       ('...', 'SE'): 1}),
#              721: Counter({('이경영', 'NNP'): 1,
#                       ('신선', 'XR'): 1,
#                       ('돋보이', 'VV'): 1,
#                       ('영화', 'NNG'): 1}),
#              722: Counter({('기억', 'NNG'): 1, ('어요', 'EC'): 1}),
#              728: Counter({('만화', 'NNP'): 1,
#                       ('영화', 'NNP'): 1,
#                       ('인줄', 'NNG'): 1,
#                       ('볼거리', 'NNG'): 1,
#                       ('아서', 'EC'): 1,
#                       ('눈요기', 'NNG'): 1,
#                       ('지만', 'EF'): 1,
#                       ('스토리', 'NNP'): 1}),
#              735: Counter({('솔직히', 'MAG'): 1,
#                       ('ㄹㅇ다들', 'NA'): 1,
#                       ('재밌', 'VA'): 1}),
#              743: Counter({('그냥', 'MAG'): 1,
#                       ('..', 'SE'): 1,
#                       ('일반', 'NNG'): 1,
#                       ('한국', 'NNP'): 1,
#                       ('공포', 'NNP'): 1,
#                       ('영화', 'NNP'): 1,
#                       ('진짜', 'MAG'): 1,
#                       ('댓글', 'NNP'): 1,
#                       ('알바', 'NNP'): 1,
#                       ('는데', 'EC'): 1,
#                       ('아요', 'EF'): 1,
#                       ('...', 'SE'): 1,
#                       ('너무', 'MAG'): 1,
#                       ('뻔하', 'VA'): 1,
#                       ('ㅂ니다', 'EC'): 1,
#                       ('여러분', 'NNP'): 1,
#                       ('지마', 'NNG'): 1,
#                       ('진짜ㅠㅠㅠㅠ진심', 'NA'): 1}),
#              751: Counter({('예측', 'NNG'): 1,
#                       ('가능', 'XR'): 1,
#                       ('스토리', 'NNP'): 1,
#                       ('아쉽..ㅠ.ㅠ', 'NA'): 1}),
#              767: Counter({('퍼그', 'NNP'): 1,
#                       ('채우', 'VV'): 1,
#                       ('으면', 'EC'): 1,
#                       ('진짜', 'MAG'): 1,
#                       ('재미있', 'VA'): 1,
#                       ('아쉽....', 'NA'): 1}),
#              778: Counter({('거르', 'VV'): 1,
#                       ('한국', 'NNP'): 1,
#                       ('영화', 'NNP'): 1}),
#              780: Counter({('별점', 'NNG'): 1,
#                       ('못하', 'VX'): 1,
#                       ('..', 'SE'): 1,
#                       ('다운사이징', 'NNP'): 1,
#                       ('두샨', 'NNP'): 1,
#                       ('까지만재밋음주제는', 'NA'): 1,
#                       ('은데', 'EC'): 1,
#                       ('갈수록', 'MAG'): 1,
#                       ('감독', 'NNG'): 1,
#                       ('의도', 'NNG'): 1,
#                       ('바가뭔지모르겟다', 'NA'): 1}),
#              786: Counter({('반 주', 'NNP'): 1,
#                       ('기도', 'NNP'): 1,
#                       ('아깝', 'VA'): 1,
#                       ('나름', 'NNB'): 1,
#                       ('살리', 'VV'): 1,
#                       ('ㄴ다면', 'EC'): 1,
#                       ('흥미', 'NNG'): 1,
#                       ('소재', 'NNG'): 1,
#                       ('훌륭', 'XR'): 1,
#                       ('배우', 'NNG'): 1,
#                       ('데리', 'VV'): 1,
#                       ('연출', 'NNG'): 1,
#                       ('말아먹', 'VV'): 1,
#                       ('안타깝', 'VA'): 1,
#                       ('그냥', 'MAG'): 1}),
#              795: Counter({('대체', 'NNG'): 1,
#                       ('굳이', 'MAG'): 1,
#                       ('..', 'SE'): 2,
#                       ('블랙', 'NNP'): 1,
#                       ('설정', 'NNG'): 1,
#                       ('거지', 'NNG'): 1}),
#              803: Counter({('도대체', 'MAG'): 1,
#                       ('ㅡㅡ', 'NA'): 1,
#                       ('어이없', 'VA'): 1}),
#              804: Counter({('강동원', 'NNP'): 1,
#                       ('어벙한', 'NA'): 1,
#                       ('연기', 'NNG'): 1,
#                       ('진짜', 'MAG'): 1,
#                       ('최악', 'NNG'): 1}),
#              814: Counter({('ㄴ데', 'EF'): 1,
#                       ('인간', 'NNG'): 1,
#                       ('기계', 'NNG'): 1}),
#              816: Counter({('한국', 'NNP'): 1,
#                       ('영화', 'NNP'): 1,
#                       ('아시아', 'NNP'): 1,
#                       ('최초', 'NNG'): 1,
#                       ('황금종려상', 'NNP'): 1,
#                       ('는데', 'EC'): 1,
#                       ('이것', 'NP'): 1,
#                       ('천만', 'NR'): 1,
#                       ('생기', 'VV'): 1,
#                       ('어서', 'EC'): 1,
#                       ('ㄴ다', 'EF'): 1}),
#              819: Counter({('여기', 'NP'): 1,
#                       ('나오', 'VV'): 1,
#                       ('사람', 'NNG'): 1,
#                       ('평균', 'NNP'): 1,
#                       ('지능', 'NNP'): 1,
#                       ('40', 'SN'): 1,
#                       ('세계관', 'NNG'): 1,
#                       ('ㅂ니다', 'EC'): 1}),
#              822: Counter({('한국', 'NNP'): 1,
#                       ('드라마', 'NNG'): 1,
#                       ('보다', 'JKB'): 1,
#                       ('답답', 'XR'): 1,
#                       ('영화', 'NNG'): 2,
#                       ('...', 'SE'): 1,
#                       ('이런', 'MM'): 1,
#                       ('좋아한다니ㅋㅋㅋ', 'NA'): 1}),
#              824: Counter({('역시', 'MAJ'): 1,
#                       ('..', 'SE'): 1,
#                       ('걸러야..ㅋㅋ', 'NA'): 1}),
#              830: Counter({('엄복동', 'NNP'): 1,
#                       ('피하', 'VV'): 2,
#                       ('는데', 'EC'): 1,
#                       ('이거', 'NP'): 1}),
#              834: Counter({('정치색', 'NNG'): 1}),
#              850: Counter({('소리', 'NNG'): 1, ('도대체', 'MAG'): 1}),
#              862: Counter({('노팅힐', 'NNP'): 1,
#                       ('짝퉁....부끄러운줄', 'NA'): 1,
#                       ('아야지', 'EC'): 1}),
#              864: Counter({('로맨스', 'NNP'): 1,
#                       ('정치', 'NNG'): 1,
#                       ('하나', 'NR'): 1,
#                       ('하지', 'NNP'): 1,
#                       ('너무', 'MAG'): 1,
#                       ('지루', 'XR'): 1}),
#              876: Counter({('10', 'SN'): 1,
#                       ('짜리', 'XSN'): 1,
#                       ('이상', 'NNG'): 1,
#                       ('알바', 'NNP'): 1}),
#              901: Counter({('보다', 'MAG'): 1,
#                       ('ㄹ루', 'JKB'): 1,
#                       ('지루함', 'NNP'): 1}),
#              902: Counter({('2500', 'SN'): 1,
#                       ('날렸넹', 'NA'): 1,
#                       ('정말', 'MAG'): 1,
#                       ('재미없', 'VA'): 2,
#                       ('기생충', 'NNG'): 1,
#                       ('보고', 'JKB'): 1,
#                       ('호기심', 'NNG'): 1,
#                       ('봤는뎅', 'NA'): 1,
#                       ('아무도 모른다', 'NNP'): 1,
#                       ('라는', 'ETM'): 1,
#                       ('영화', 'NNG'): 2,
#                       ('비슷', 'XR'): 1,
#                       ('너무', 'MAG'): 2,
#                       ('지루함', 'NNP'): 1,
#                       ('어서', 'EC'): 1,
#                       ('영원히', 'MAG'): 1,
#                       ('기억', 'NNG'): 1}),
#              908: Counter({('다음', 'NNG'): 1,
#                       ('남조', 'NNP'): 1,
#                       ('오나라', 'NNP'): 1,
#                       ('나라', 'NNP'): 1,
#                       ('후손', 'NNG'): 1,
#                       ('전라', 'NNP'): 1,
#                       ('왜구', 'NNP'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('깔깔깔', 'MAG'): 1}),
#              916: Counter({('몰입', 'NNG'): 1,
#                       ('힘들', 'VA'): 1,
#                       ('영화', 'NNP'): 1,
#                       ('네요', 'EF'): 1}),
#              917: Counter({('한쿡영화ㅎㅎ', 'NA'): 1}),
#              921: Counter({('ㅋㅋ', 'NA'): 1,
#                       ('댓글', 'NNP'): 1,
#                       ('알바', 'NNP'): 1,
#                       ('존재', 'NNG'): 1,
#                       ('는구나', 'EC'): 1}),
#              922: Counter({('애새끼', 'NNG'): 1,
#                       ('데리', 'VV'): 1,
#                       ('아서', 'EC'): 2,
#                       ('떠들', 'VV'): 1,
#                       ('조용히', 'MAG'): 1,
#                       ('시키', 'VV'): 1,
#                       ('어라', 'EF'): 1,
#                       ('심지어', 'MAG'): 1,
#                       ('놓아두', 'VV'): 1,
#                       ('부모', 'NNG'): 1,
#                       ('나가', 'VV'): 1,
#                       ('볼일', 'NNG'): 1,
#                       ('특정', 'NNG'): 1,
#                       ('시간', 'NNG'): 1,
#                       ('키즈', 'NNG'): 1,
#                       ('타임', 'NNP'): 1,
#                       ('라도', 'EC'): 1,
#                       ('만들', 'VV'): 1,
#                       ('던가', 'EF'): 1}),
#              923: Counter({('김래원', 'NNP'): 1,
#                       ('박신양', 'NNP'): 1,
#                       ('박희순', 'NNP'): 1,
#                       ('개그맨', 'NNP'): 1,
#                       ('8년', 'NNP'): 1,
#                       ('재미없', 'VA'): 1,
#                       ('해바라기', 'NNP'): 1,
#                       ('이다', 'NNP'): 1,
#                       ('간지', 'NNP'): 1,
#                       ('최고', 'NNG'): 1}),
#              924: Counter({('..', 'SE'): 1,
#                       ('진짜', 'MAG'): 1,
#                       ('이거', 'NP'): 1,
#                       ('는데', 'EC'): 1,
#                       ('데이터', 'NNG'): 1,
#                       ('아깝', 'VA'): 1}),
#              936: Counter({('실망', 'NNG'): 2,
#                       ('영화', 'NNG'): 1,
#                       ('강동원', 'NNP'): 1}),
#              940: Counter({('때문', 'NNB'): 1,
#                       ('억지로', 'MAG'): 1,
#                       ('아이디어', 'NNG'): 1,
#                       ('짜내', 'VV'): 1,
#                       ('어서', 'EC'): 1,
#                       ('시리즈', 'NNG'): 1,
#                       ('지속', 'NNG'): 1,
#                       ('려고', 'EC'): 1,
#                       ('노력', 'NNG'): 1,
#                       ('지만', 'EC'): 1,
#                       ('전작', 'NNG'): 1,
#                       ('짜임새', 'NNG'): 1,
#                       ('플롯', 'NNP'): 1,
#                       ('재현', 'NNG'): 1,
#                       ('해내', 'VV'): 1,
#                       ('에서', 'JKB'): 1,
#                       ('너무', 'MAG'): 1,
#                       ('깔끔', 'XR'): 1,
#                       ('내버리', 'VV'): 1,
#                       ('한마디', 'NNG'): 1}),
#              948: Counter({('알바', 'NNP'): 1,
#                       ('왤케', 'NA'): 1,
#                       ('설치', 'VV'): 1,
#                       ('...', 'SE'): 1}),
#              949: Counter({('드러나', 'VV'): 1,
#                       ('안타깝', 'VA'): 1,
#                       ('많겟지그런데', 'NA'): 1,
#                       ('재미', 'NNG'): 1,
#                       ('대사도', 'NNP'): 1,
#                       ('그렇', 'VA'): 1,
#                       ('생각', 'NNG'): 1,
#                       ('대로', 'NNP'): 1,
#                       ('흘러가', 'VV'): 1,
#                       ('무난', 'XR'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('재미없', 'VA'): 1}),
#              958: Counter({('고생', 'NNG'): 1,
#                       ('습니다', 'EC'): 1,
#                       ('맛있', 'VA'): 1,
#                       ('보이', 'VV'): 1,
#                       ('네요', 'EC'): 1}),
#              966: Counter({('진짜', 'MAG'): 1,
#                       ('개쌉노잼입니다,,', 'NA'): 1,
#                       ('범죄도시', 'NNP'): 1,
#                       ('흥하', 'VV'): 1,
#                       ('다고', 'EC'): 1,
#                       ('너무', 'MAG'): 1,
#                       ('우려먹', 'VV'): 1,
#                       ('마지막', 'NNG'): 1,
#                       ('억지로', 'MAG'): 1,
#                       ('웃음', 'NNP'): 1,
#                       ('짜내', 'VV'): 1,
#                       ('려는', 'ETM'): 1,
#                       ('설정', 'NNG'): 1,
#                       ('최근', 'NNG'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('제일', 'NNG'): 1,
#                       ('재미', 'NNP'): 1,
#                       ('아깝', 'VA'): 1}),
#              968: Counter({('재난 영화', 'NNP'): 1,
#                       ('가장', 'MAG'): 1,
#                       ('코디', 'NNG'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('사투리', 'NNG'): 1,
#                       ('아니', 'VCN'): 1,
#                       ('한국', 'NNP'): 1,
#                       ('영화', 'NNP'): 1,
#                       ('어떻', 'VA'): 1,
#                       ('만들', 'VV'): 1,
#                       ('려나', 'EC'): 1,
#                       ('...', 'SE'): 1}),
#              969: Counter({('유치', 'XR'): 1,
#                       ('재미없', 'VA'): 1,
#                       ('개인', 'NNG'): 1,
#                       ('취향', 'NNG'): 1,
#                       ('따르', 'VV'): 1,
#                       ('지만', 'EC'): 1,
#                       ('킬링타임', 'NNP'): 1,
#                       ('으로', 'JKB'): 2,
#                       ('아도', 'EC'): 1,
#                       ('시간', 'NNG'): 1,
#                       ('아깝', 'VA'): 1,
#                       ('평점', 'NNG'): 1,
#                       ('남기', 'VV'): 1,
#                       ('ㅂ니다', 'EF'): 1,
#                       ('너무', 'MAG'): 1,
#                       ('어이없', 'VA'): 1,
#                       ('어서', 'EF'): 1}),
#              973: Counter({('우디', 'NNP'): 2,
#                       ('치우', 'VV'): 1,
#                       ('자기', 'NP'): 1,
#                       ('친구', 'NNG'): 1,
#                       ('걸리', 'VV'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('실망', 'NNG'): 1}),
#              976: Counter({('어지간', 'XR'): 1,
#                       ('까지', 'JX'): 1,
#                       ('는데', 'EC'): 1,
#                       ('이건', 'NNP'): 1,
#                       ('진짜', 'MAG'): 1}),
#              981: Counter({('마블', 'NNP'): 1,
#                       ('인기', 'NNG'): 1,
#                       ('제대로', 'MAG'): 1,
#                       ('무임승차', 'NNG'): 1,
#                       ('려는', 'ETM'): 1,
#                       ('영화', 'NNG'): 2,
#                       ('...', 'SE'): 2,
#                       ('토르', 'NNP'): 1,
#                       ('발키리', 'NNP'): 1,
#                       ('이슈', 'NNG'): 1,
#                       ('아니', 'VCN'): 1,
#                       ('아무것', 'NNG'): 1}),
#              984: Counter({('닭대가리', 'NNG'): 1,
#                       ('칼로', 'NNP'): 1,
#                       ('자르', 'VV'): 1,
#                       ('장면', 'NNG'): 1,
#                       ('박근혜', 'NNP'): 1,
#                       ('탄핵', 'NNP'): 1,
#                       ('우익', 'NNP'): 1,
#                       ('기독교', 'NNP'): 1,
#                       ('빨갱이', 'NNP'): 2,
#                       ('영화', 'NNG'): 2,
#                       ('문재인', 'NNP'): 2,
#                       ('민주당', 'NNP'): 1,
#                       ('전형', 'NNG'): 1,
#                       ('나라', 'NNG'): 1,
#                       ('공산', 'NNP'): 1,
#                       ('국가', 'NNP'): 1,
#                       ('만들', 'VV'): 1,
#                       ('탄핵', 'NNG'): 1,
#                       ('시키', 'XSV'): 1,
#                       ('어야지', 'EC'): 1,
#                       ('OO', 'NNP'): 1}),
#              986: Counter({('상품', 'NNG'): 2,
#                       ('아니', 'VCN'): 1,
#                       ('그리고', 'MAJ'): 1,
#                       ('미스', 'NNP'): 1,
#                       ('캐스팅', 'NNP'): 1,
#                       ('향연', 'NNP'): 1}),
#              991: Counter({('조금', 'MAG'): 1,
#                       ('다가', 'EC'): 1,
#                       ('네요', 'EF'): 2,
#                       ('공포', 'NNG'): 2,
#                       ('영화', 'NNG'): 1,
#                       ('ㄴ데', 'EC'): 1,
#                       ('정은지', 'NNP'): 1,
#                       ('좋아하', 'VV'): 1,
#                       ('아서', 'EC'): 1,
#                       ('본건', 'NNG'): 1,
#                       ('으로', 'JKB'): 1,
#                       ('극복', 'NNG'): 1,
#                       ('네요', 'EC'): 1,
#                       ('...', 'SE'): 1}),
#              998: Counter({('오리지널', 'NNG'): 1,
#                       ('사탄', 'NNP'): 1,
#                       ('인형', 'NNG'): 1,
#                       ('비하', 'VV'): 1,
#                       ('도안', 'NNP'): 1,
#                       ('무섭', 'VA'): 1,
#                       ('공포감', 'NNG'): 1,
#                       ('제로', 'NNP'): 1,
#                       ('...', 'SE'): 1,
#                       ('그냥', 'MAG'): 1,
#                       ('잔인', 'XR'): 1}),
#              1001: Counter({('라도', 'EC'): 1,
#                       ('향우회', 'NNP'): 1,
#                       ('키드', 'NNP'): 1,
#                       ('발악을하네ㅉㅉ', 'NA'): 1}),
#              1005: Counter({('이서', 'NNP'): 1,
#                       ('33000', 'SN'): 1,
#                       ('내놓', 'VV'): 2,
#                       ('아라', 'EF'): 1,
#                       ('SF', 'SL'): 1,
#                       ('행동', 'NNG'): 1,
#                       ('으로', 'JKB'): 1,
#                       ('보이', 'VV'): 1,
#                       ('어야지', 'EC'): 1,
#                       ('!!!', 'NNP'): 1,
#                       ('불대', 'NNG'): 1,
#                       ('다가', 'JX'): 1,
#                       ('허무', 'NNG'): 1,
#                       ('끝나', 'VV'): 1,
#                       ('...', 'SE'): 2}),
#              1009: Counter({('이상', 'NNG'): 1,
#                       ('국산', 'NNG'): 1,
#                       ('영화', 'NNG'): 2,
#                       ('평점', 'NNG'): 3,
#                       ('네요', 'EC'): 2,
#                       ('그만큼', 'MAG'): 1,
#                       ('흥행', 'NNG'): 1,
#                       ('역활', 'NNG'): 1,
#                       ('ㄴ다는', 'ETM'): 1,
#                       ('알바', 'NNP'): 1,
#                       ('때문', 'NNB'): 1,
#                       ('신뢰', 'NNG'): 1,
#                       ('떨어지', 'VV'): 1}),
#              1011: Counter({('완벽', 'NNG'): 1,
#                       ('말아먹', 'VV'): 1,
#                       ('영화', 'NNG'): 1}),
#              1028: Counter({('영화', 'NNG'): 1,
#                       ('보다', 'JKB'): 2,
#                       ('너무', 'MAG'): 1,
#                       ('이상', 'NNG'): 1,
#                       ('아서', 'EC'): 1,
#                       ('그렇', 'VA'): 1,
#                       ('느끼', 'VV'): 1,
#                       ('ㄴ가', 'EC'): 1,
#                       ('들어오', 'VV'): 1,
#                       ('역시', 'MAJ'): 1,
#                       ('배우', 'NNP'): 1,
#                       ('아깝', 'VA'): 1}),
#              1031: Counter({('평점', 'NNG'): 1,
#                       ('재미없', 'VA'): 1,
#                       ('기도', 'NNG'): 1}),
#              1048: Counter({('VOD', 'SL'): 1,
#                       ('금방', 'MAG'): 1,
#                       ('올라오', 'VV'): 1}),
#              1049: Counter({('주연', 'NNG'): 1,
#                       ('연기', 'NNP'): 1,
#                       ('진짜', 'MAG'): 1,
#                       ('더럽', 'VA'): 1,
#                       ('못하', 'VX'): 1}),
#              1050: Counter({('유치해요.ㅠㅠ내쿠폰..ㅠ', 'NA'): 1}),
#              1053: Counter({('디즈니', 'NNP'): 1,
#                       ('내리', 'VV'): 1,
#                       ('어야', 'EC'): 1,
#                       ('머리', 'NNG'): 1,
#                       ('남기', 'VV'): 1,
#                       ('이미지', 'NNP'): 1,
#                       ('향연', 'NNP'): 1}),
#              1058: Counter({('시간', 'NNG'): 1,
#                       ('낭비', 'NNG'): 1,
#                       ('커피', 'NNG'): 1,
#                       ('한잔', 'NNG'): 1}),
#              1060: Counter({('김래원', 'NNP'): 1,
#                       ('사투리', 'NNG'): 1,
#                       ('들어주', 'VV'): 1,
#                       ('원진', 'NNP'): 1,
#                       ('연기', 'NNG'): 1,
#                       ('...', 'SE'): 1}),
#              1079: Counter({('류준열', 'NNP'): 1}),
#              1081: Counter({('이렇', 'VA'): 1,
#                       ('어서', 'EC'): 2,
#                       ('원작', 'NNG'): 1,
#                       ('사람', 'NNG'): 1,
#                       ('ㄴ다는', 'ETM'): 1,
#                       ('새로', 'MAG'): 1,
#                       ('깨닫', 'VV'): 1,
#                       ('어요', 'EF'): 1,
#                       ('영화', 'NNG'): 2,
#                       ('나름', 'NNB'): 1,
#                       ('괜찮', 'VA'): 1,
#                       ('ㄴ데', 'EC'): 1,
#                       ('웹툰', 'NNP'): 1,
#                       ('으로', 'JKB'): 1,
#                       ('무서움', 'NNG'): 1,
#                       ('이나', 'JX'): 1,
#                       ('지나', 'VV'): 1,
#                       ('지금', 'NNG'): 1,
#                       ('기억나', 'VV'): 1,
#                       ('는데', 'EC'): 1,
#                       ('ㄴ가', 'EC'): 1,
#                       ('너무', 'MAG'): 1,
#                       ('전개', 'NNG'): 1,
#                       ('예상', 'NNG'): 1,
#                       ('스토리', 'NNP'): 1,
#                       ('...', 'SE'): 1}),
#              1083: Counter({('처키', 'NNP'): 1,
#                       ('생기', 'VV'): 1,
#                       ('이상해', 'NNP'): 1}),
#              1104: Counter({('감독', 'NNG'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('마지막', 'NNG'): 1,
#                       ('갑자기', 'MAG'): 1,
#                       ('배우', 'NNG'): 1,
#                       ('에게', 'JKB'): 1,
#                       ('노래', 'NNG'): 1,
#                       ('시키', 'VV'): 1,
#                       ('이유', 'NNG'): 1,
#                       ('만들', 'VV'): 1,
#                       ('보니', 'NNP'): 1,
#                       ('ㄴ가', 'EC'): 1,
#                       ('아쉽', 'VA'): 1,
#                       ('어서', 'EC'): 1,
#                       ('라도', 'EC'): 1,
#                       ('해보', 'VV'): 1,
#                       ('려고', 'EC'): 1}),
#              1114: Counter({('재미없', 'VA'): 1, ('더라', 'EC'): 1}),
#              1117: Counter({('중간', 'NNG'): 1,
#                       ('바르', 'VA'): 1,
#                       ('표현', 'NNG'): 3,
#                       ('섬뜩', 'MAG'): 1,
#                       ('...', 'SE'): 3,
#                       ('도대체', 'MAG'): 1,
#                       ('저런', 'MM'): 1,
#                       ('연출', 'NNP'): 1,
#                       ('애도', 'NNG'): 1}),
#              1118: Counter({('...', 'SE'): 1,
#                       ('실시간', 'NNP'): 1,
#                       ('으로', 'JKB'): 1,
#                       ('영화관', 'NNP'): 2,
#                       ('ㅂ니다', 'EC'): 1,
#                       ('끝나', 'VV'): 1,
#                       ('30', 'SN'): 1,
#                       ('나가', 'VV'): 1,
#                       ('아서', 'EC'): 1,
#                       ('버티는즁..', 'NA'): 1,
#                       ('에서', 'JKB'): 1,
#                       ('맛집', 'NNG'): 1,
#                       ('탐색', 'NNG'): 1,
#                       ('처음', 'NNP'): 1,
#                       ('..', 'SE'): 1,
#                       ('김래원', 'NNP'): 1,
#                       ('연기', 'NNP'): 1,
#                       ('아깝', 'VA'): 1,
#                       ('어요', 'EC'): 1,
#                       ('ㅜㅜ', 'NA'): 1}),
#              1131: Counter({('공산주의자', 'NNG'): 1,
#                       ('미화', 'NNG'): 1,
#                       ('영화', 'NNG'): 2,
#                       ('ㄴ가', 'EF'): 2,
#                       ('아니', 'VCN'): 1,
#                       ('공산주의', 'NNP'): 1,
#                       ('진실', 'NNG'): 1,
#                       ('보이', 'VV'): 1,
#                       ('의도', 'NNG'): 1,
#                       ('궁금', 'XR'): 1}),
#              1136: Counter({('평점', 'NNG'): 1,
#                       ('알바', 'NNP'): 1,
#                       ('대단', 'XR'): 1,
#                       ('네요', 'EC'): 1,
#                       ('얼마나', 'MAG'): 1,
#                       ('으시', 'EP'): 1,
#                       ('어요', 'EC'): 1}),
#              1139: Counter({('내용', 'NNG'): 1,
#                       ('이상해', 'NNP'): 1,
#                       ('요점', 'NNG'): 1,
#                       ('감동', 'NNG'): 1,
#                       ('깨닫', 'VV'): 1,
#                       ('거나', 'EC'): 1,
#                       ('미도', 'NNP'): 1,
# ...
#                       ('처음', 'NNG'): 1}),
#              7026: Counter({('필요', 'NNG'): 1,
#                       ('없이', 'MAG'): 1,
#                       ('...', 'SE'): 2,
#                       ('재미없', 'VA'): 1,
#                       ('어요', 'EF'): 1}),
#              7028: Counter({('강동원', 'NNP'): 1,
#                       ('배우', 'NNP'): 1,
#                       ('요즘', 'NNG'): 2,
#                       ('따라', 'JX'): 1,
#                       ('고르', 'VV'): 1,
#                       ('작품', 'NNG'): 1,
#                       ('마다', 'JX'): 1,
#                       ('걸리', 'VV'): 1,
#                       ('는지', 'EC'): 1,
#                       ('참담', 'XR'): 1,
#                       ('예전', 'NNG'): 1,
#                       ('우리들의 행복한 시간', 'NNP'): 1,
#                       ('영화', 'NNP'): 1,
#                       ('의형제', 'NNP'): 1,
#                       ('등등', 'NNB'): 2,
#                       ('이런', 'MM'): 1,
#                       ('명작', 'NNG'): 1,
#                       ('는데', 'EC'): 1,
#                       ('골든', 'NNG'): 1,
#                       ('슬럼', 'NNP'): 1,
#                       ('에다가', 'JKB'): 1}),
#              7033: Counter({('시리즈', 'NNG'): 3,
#                       ('ㄹ수록', 'EC'): 1,
#                       ('이해', 'NNG'): 1,
#                       ('불가', 'NNG'): 1,
#                       ('작품', 'NNG'): 1,
#                       ('작가', 'NNG'): 1,
#                       ('도대체', 'MAG'): 1,
#                       ('무슨', 'MM'): 1,
#                       ('생각', 'NNG'): 1,
#                       ('으로', 'JKB'): 1,
#                       ('쓰느건지', 'NA'): 1,
#                       ('의도', 'NNP'): 1,
#                       ('밝히', 'VV'): 1,
#                       ('!!', 'NNP'): 1,
#                       ('이렇', 'VA'): 1,
#                       ('주인공', 'NNG'): 1,
#                       ('중복', 'NNG'): 1,
#                       ('라고', 'EC'): 1,
#                       ('으면', 'EC'): 1,
#                       ('...', 'SE'): 1}),
#              7044: Counter({('dx', 'SL'): 1,
#                       ('는데', 'EC'): 1,
#                       ('의자', 'NNG'): 1,
#                       ('흔들리', 'VV'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('보다', 'JKB'): 1,
#                       ('재밌', 'VA'): 1,
#                       ('네요', 'EC'): 1,
#                       ('ㅎㅎ', 'NA'): 1}),
#              7062: Counter({('영화', 'NNG'): 2,
#                       ('처음', 'NNG'): 1,
#                       ('부터', 'JX'): 1,
#                       ('까지', 'JX'): 1,
#                       ('개연', 'NNG'): 1,
#                       ('하나', 'NR'): 1,
#                       ('억지웃음', 'NNG'): 1,
#                       ('질리', 'VV'): 1,
#                       ('ㄴ다', 'EC'): 1,
#                       ('알바', 'NNP'): 1,
#                       ('고생', 'NNG'): 1,
#                       ('네요', 'EC'): 1}),
#              7067: Counter({('영화', 'NNG'): 1,
#                       ('라고', 'EC'): 1,
#                       ('만들', 'VV'): 1,
#                       ('ㄴ가', 'EF'): 1,
#                       ('리얼', 'NNP'): 1,
#                       ('블랙', 'NNP'): 1,
#                       ('수치', 'NNG'): 1}),
#              7069: Counter({('페미,', 'NA'): 1,
#                       ('PC', 'SL'): 1,
#                       ('끼얹', 'VV'): 1,
#                       ('으면', 'EC'): 1,
#                       ('이렇', 'VA'): 1,
#                       ('습니다', 'EC'): 1}),
#              7071: Counter({('진짜', 'MAG'): 1,
#                       ('재밌', 'VA'): 1,
#                       ('다고', 'EC'): 1,
#                       ('....', 'SE'): 1,
#                       ('형편없', 'VA'): 1,
#                       ('영화', 'NNG'): 2,
#                       ('흔하', 'VA'): 1,
#                       ('위기', 'NNG'): 1,
#                       ('극복', 'NNG'): 1,
#                       ('어린이', 'NNG'): 1,
#                       ('ㄴ데', 'EC'): 1,
#                       ('세상', 'NNG'): 1,
#                       ('뻔하', 'VA'): 1,
#                       ('아서', 'EC'): 1,
#                       ('아도', 'EC'): 1,
#                       ('내용', 'NNG'): 1,
#                       ('너무', 'MAG'): 1,
#                       ('보이', 'VV'): 1,
#                       ('과연', 'MAG'): 1,
#                       ('버튼', 'NNP'): 1,
#                       ('만들', 'VV'): 1,
#                       ('ㄴ가', 'EC'): 1,
#                       ('감동', 'NNG'): 2,
#                       ('스럽', 'XSA'): 3,
#                       ('은데', 'EC'): 1,
#                       ('자꾸', 'MAG'): 1,
#                       ('려고', 'EC'): 1,
#                       ('...', 'SE'): 1,
#                       ('억지', 'NNG'): 1,
#                       ('몹시', 'MAG'): 1,
#                       ('실망', 'NNG'): 1}),
#              7081: Counter({('알라딘', 'NNP'): 1,
#                       ('ㄹ껄', 'EF'): 1,
#                       ('...', 'SE'): 1,
#                       ('괜히', 'MAG'): 1}),
#              7090: Counter({('ㅋㅋ웃음밖에안나옴.', 'NA'): 1}),
#              7092: Counter({('아깝', 'VA'): 1,
#                       ('어요', 'EC'): 1,
#                       ('쓰레기', 'NNP'): 1}),
#              7095: Counter({('뺑반이', 'NA'): 1,
#                       ('훨씬', 'MAG'): 1,
#                       ('재밌', 'VA'): 1,
#                       ('으로', 'JKB'): 1,
#                       ('평점', 'NNG'): 1,
#                       ('천만', 'NR'): 1,
#                       ('다니', 'EC'): 1,
#                       ('부끄럽', 'VA'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('이그', 'NNP'): 1,
#                       ('!!', 'NNP'): 1}),
#              7096: Counter({('쟁이', 'XSN'): 1,
#                       ('나오', 'VV'): 1,
#                       ('그렇', 'VA'): 1,
#                       ('재밌', 'VA'): 1,
#                       ('다는', 'ETM'): 1,
#                       ('거지', 'NNG'): 1,
#                       ('양키', 'NNP'): 1,
#                       ('니까', 'EC'): 1,
#                       ('멋지', 'VA'): 1,
#                       ('보이', 'VV'): 1}),
#              7102: Counter({('괜히', 'MAG'): 1,
#                       ('버리', 'VX'): 1,
#                       ('까지', 'JX'): 1,
#                       ('쓰레기', 'NNG'): 1,
#                       ('기분', 'NNG'): 2,
#                       ('정신', 'NNG'): 1,
#                       ('에서', 'JKB'): 1,
#                       ('냄새', 'NNG'): 1,
#                       ('기분', 'NNP'): 1,
#                       ('나오', 'VV'): 2,
#                       ('짜증', 'NNG'): 1,
#                       ('보기', 'NNP'): 1,
#                       ('으로', 'JKB'): 1,
#                       ('돌아가', 'VV'): 1}),
#              7111: Counter({('같이', 'MAG'): 1,
#                       ('관객', 'NNG'): 1,
#                       ('전부', 'MAG'): 1,
#                       ('나오', 'VV'): 1,
#                       ('던데', 'EC'): 1,
#                       ('여기', 'NP'): 1,
#                       ('니까', 'EC'): 1,
#                       ('평점', 'NNG'): 1,
#                       ('10', 'SN'): 1,
#                       ('인생', 'NNP'): 1,
#                       ('최고', 'NNP'): 1,
#                       ('영화', 'NNP'): 1,
#                       ('티켓', 'NNP'): 1,
#                       ('환불', 'NNG'): 1,
#                       ('ㄴ다', 'EF'): 1}),
#              7113: Counter({('정말', 'MAG'): 1,
#                       ('간만', 'NNG'): 1,
#                       ('영화관', 'NNP'): 1,
#                       ('에서', 'JKB'): 1}),
#              7114: Counter({('재앙', 'NNG'): 1,
#                       ('비기닝', 'NA'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('한편', 'NNG'): 1,
#                       ('으로', 'JKB'): 1,
#                       ('한국경제', 'NNP'): 1,
#                       ('나비효과', 'NNP'): 1,
#                       ('일어나', 'VV'): 1}),
#              7118: Counter({('ㄴ가', 'EC'): 1,
#                       ('영화', 'NNP'): 2,
#                       ('진짜', 'MAG'): 1,
#                       ('가볍', 'VA'): 1}),
#              7130: Counter({('영화', 'NNG'): 2,
#                       ('채널', 'NNP'): 2,
#                       ('나오', 'VV'): 1,
#                       ('리다', 'NNP'): 1,
#                       ('시간', 'NNG'): 1,
#                       ('우기', 'NNP'): 1,
#                       ('느낌', 'NNP'): 1,
#                       ('그냥', 'MAG'): 1,
#                       ('때리', 'VV'): 1,
#                       ('더니', 'EC'): 1,
#                       ('끝나', 'VV'): 1}),
#              7141: Counter({('아서', 'EC'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('는데', 'EC'): 1,
#                       ('수준', 'NNG'): 1,
#                       ('못되', 'VA'): 1,
#                       ('ㄴ다', 'EC'): 1}),
#              7143: Counter({('배우', 'VV'): 1,
#                       ('나오', 'VV'): 1,
#                       ('유해진', 'NNP'): 1,
#                       ('엄청', 'MAG'): 1,
#                       ('오바', 'NNG'): 2,
#                       ('자기', 'NP'): 1,
#                       ('영화', 'NNP'): 1,
#                       ('가장', 'MAG'): 1,
#                       ('좋아하', 'VV'): 1,
#                       ('장면', 'NNG'): 1,
#                       ('아서', 'EC'): 1,
#                       ('ㅋㅋ', 'NA'): 1}),
#              7147: Counter({('뻔하', 'VA'): 1,
#                       ('전형', 'NNG'): 1,
#                       ('한국', 'NNP'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('급감', 'NNG'): 1,
#                       ('자욱', 'XR'): 1,
#                       ('역겹', 'VA'): 1}),
#              7148: Counter({('중간', 'NNG'): 1,
#                       ('나오', 'VV'): 1,
#                       ('정도', 'NNG'): 1}),
#              7156: Counter({('감독', 'NNG'): 2,
#                       ('틀리', 'VV'): 1,
#                       ('잖아', 'EC'): 1,
#                       ('원래', 'NNG'): 1,
#                       ('어디', 'NP'): 1,
#                       ('!!', 'NNP'): 1}),
#              7179: Counter({('설정', 'NNP'): 1,
#                       ('자체', 'NNP'): 1,
#                       ('너무', 'MAG'): 2,
#                       ('이안', 'NNG'): 1,
#                       ('부터', 'JX'): 1,
#                       ('시작', 'NNG'): 1,
#                       ('아서', 'EC'): 2,
#                       ('무섭', 'VA'): 1,
#                       ('는커녕', 'JX'): 1,
#                       ('웃음이나오는ㅋㅋㅋ요즘한국', 'NA'): 1,
#                       ('공포', 'NNP'): 1,
#                       ('스릴러', 'NNP'): 1,
#                       ('장르', 'NNP'): 1,
#                       ('따위', 'NNB'): 1,
#                       ('에요', 'EF'): 1,
#                       ('마지막', 'NNG'): 1,
#                       ('결말', 'NNG'): 1,
#                       ('급조', 'NNG'): 1,
#                       ('..', 'SE'): 2,
#                       ('감독', 'NNP'): 1,
#                       ('작품', 'NNG'): 1,
#                       ('치고', 'JX'): 1,
#                       ('쓰레기', 'NNG'): 1,
#                       ('ㅂ니다', 'EC'): 1,
#                       ('이건', 'NNP'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('대하', 'VV'): 1,
#                       ('모독', 'NNG'): 1,
#                       ('수준', 'NNG'): 1,
#                       ('그나마', 'MAG'): 1,
#                       ('라고', 'NNP'): 1,
#                       ('강예원', 'NNP'): 1,
#                       ('연기', 'NNP'): 1,
#                       ('정도', 'NNP'): 1,
#                       ('...', 'SE'): 1}),
#              7181: Counter({('....ㅣ지딕ㄷㄱ치ㅢㅈ극ㅈㄱ디ㅡ', 'NA'): 1}),
#              7187: Counter({('너무', 'MAG'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('..', 'SE'): 1,
#                       ('억지', 'NNG'): 1,
#                       ('스럽', 'XSA'): 1,
#                       ('...', 'SE'): 1}),
#              7190: Counter({('다가', 'EC'): 1,
#                       ('사람', 'NNG'): 1,
#                       ('어야', 'EC'): 1,
#                       ('ㅂ니다', 'EC'): 1}),
#              7191: Counter({('아니', 'MAG'): 1,
#                       ('평정', 'NNG'): 1,
#                       ('작업', 'NNG'): 1,
#                       ('정도', 'NNG'): 1,
#                       ('아야지', 'EC'): 1,
#                       ('현실', 'NNG'): 1,
#                       ('술취', 'NNG'): 1,
#                       ('할아버지', 'NNG'): 1,
#                       ('하나', 'NR'): 1,
#                       ('제압', 'NNG'): 1,
#                       ('못하', 'VX'): 1,
#                       ('면서', 'EC'): 1,
#                       ('...', 'SE'): 1}),
#              7193: Counter({('존 윅', 'NNP'): 1,
#                       ('으로', 'JKB'): 1,
#                       ('선회', 'NNG'): 1,
#                       ('습니다', 'EF'): 1,
#                       ('감사', 'NNP'): 1,
#                       ('니다', 'EF'): 1}),
#              7203: Counter({('글쎄', 'IC'): 1, ('아깝', 'VA'): 1}),
#              7206: Counter({('독재자', 'NNP'): 1,
#                       ('찬양', 'NNG'): 1,
#                       ('쓰레기', 'NNP'): 1,
#                       ('영화', 'NNG'): 2,
#                       ('간첩', 'NNG'): 1,
#                       ('좋아하', 'VV'): 1}),
#              7207: Counter({('이렇', 'VA'): 1,
#                       ('재미없', 'VA'): 1,
#                       ('일본', 'NNP'): 1,
#                       ('영화', 'NNG'): 2,
#                       ('ㄴ다', 'EC'): 1,
#                       ('이런', 'MM'): 1,
#                       ('수입', 'NNG'): 1}),
#              7208: Counter({('북한', 'NNP'): 1,
#                       ('선전', 'NNG'): 1,
#                       ('으로', 'JKB'): 1,
#                       ('써먹', 'VV'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('이상', 'NNG'): 1,
#                       ('https', 'SL'): 1,
#                       ('news', 'SL'): 1,
#                       ('naver', 'SL'): 1,
#                       ('.com', 'NNP'): 1,
#                       ('article', 'SL'): 1,
#                       ('023', 'SN'): 1,
#                       ('0003454513', 'SN'): 1,
#                       ('ntype', 'SL'): 1,
#                       ('RANKING', 'SL'): 1}),
#              7209: Counter({('정말', 'MAG'): 1,
#                       ('재미없', 'VA'): 1,
#                       ('어요', 'EC'): 1,
#                       ('흐악', 'NA'): 1}),
#              7217: Counter({('잠온다....드르렁', 'NA'): 1}),
#              7232: Counter({('뻔하', 'VA'): 1,
#                       ('전개', 'NNG'): 1,
#                       ('반전', 'NNG'): 1,
#                       ('루즈', 'NNG'): 1,
#                       ('진행', 'NNG'): 1,
#                       ('재탕', 'NNG'): 1,
#                       ('CG', 'NNP'): 1,
#                       ('거기', 'NP'): 1,
#                       ('까지', 'JX'): 3,
#                       ('으나', 'EC'): 1,
#                       ('PC', 'SL'): 1,
#                       ('이렇', 'VA'): 1,
#                       ('내야', 'NNP'): 1,
#                       ('하나', 'NNP'): 1,
#                       ('불쾌', 'XR'): 1,
#                       ('만들', 'VV'): 2,
#                       ('차라리', 'MAG'): 1,
#                       ('WIB', 'SL'): 1,
#                       ('끼리', 'XSN'): 1,
#                       ('던가', 'EF'): 1,
#                       ('마지막 전투', 'NNP'): 1,
#                       ('장면', 'NNP'): 1,
#                       ('마저', 'JX'): 1,
#                       ('밋밋', 'XR'): 1,
#                       ('배신', 'NNP'): 1,
#                       ('어야', 'EC'): 1,
#                       ('는지', 'EC'): 1,
#                       ('언제', 'NP'): 1,
#                       ('부터', 'JX'): 1,
#                       ('변한', 'NNP'): 1,
#                       ('건지', 'NNG'): 1,
#                       ('메세지', 'NNG'): 1,
#                       ('조차', 'JX'): 1,
#                       ('전달', 'NNG'): 1,
#                       ('못하', 'VA'): 1}),
#              7233: Counter({('하여튼', 'MAG'): 1,
#                       ('멍청', 'XR'): 1,
#                       ('무식', 'NNG'): 1,
#                       ('수준', 'NNG'): 1,
#                       ('우리나라', 'NNP'): 1,
#                       ('인간', 'NNG'): 1,
#                       ('자기', 'NP'): 1,
#                       ('줏대', 'NNG'): 1,
#                       ('그저', 'MAG'): 1,
#                       ('재밌', 'VA'): 2,
#                       ('다면', 'EC'): 1,
#                       ('부화뇌동', 'NNG'): 1,
#                       ('아서', 'EC'): 1,
#                       ('다고', 'EC'): 2,
#                       ('보고', 'JKB'): 1,
#                       ('미도', 'NNP'): 1,
#                       ('삼류', 'NNG'): 1,
#                       ('영화', 'NNG'): 1,
#                       ('평점', 'NNG'): 1,
#                       ('올리', 'VV'): 1,
#                       ('한심', 'XR'): 1}),
#              7238: Counter({('어거지', 'NNG'): 1,
#                       ('줄거리', 'NNG'): 1,
#                       ('계급', 'NNP'): 1,
#                       ('주의', 'NNP'): 1,
#                       ('포르노', 'NNG'): 1}),
#              ...})

# %%
posTDM = defaultdict(Counter)
for i, posList in posDTM.items():
    for t, freq in posList.items():
        posTDM[t][i] = freq
        
negTDM = defaultdict(Counter)
for i, negList in negDTM.items():
    for t, freq in negList.items():
        negTDM[t][i] = freq

# %%
# PMI(x=uniqTerm, y=Pos/Neg)
posVoca = list(posTDM.keys())
negVoca = list(negTDM.keys())

# %%
posPOS = defaultdict(Counter)
for t in posVoca:
    posPOS[t[1]][t[0]] = sum(posTDM[t].values())
    
negPOS = defaultdict(Counter)
for t in negVoca:
    negPOS[t[1]][t[0]] = sum(negTDM[t].values())

# %%
list(zip(posPOS['NNG'].most_common()[:20],
       negPOS['NNG'].most_common()[:20]))
# Out:
# [(('영화', 480), ('영화', 576)),
#  (('생각', 117), ('평점', 108)),
#  (('연기', 81), ('시간', 62)),
#  (('기대', 60), ('사람', 60)),
#  (('사람', 48), ('감독', 59)),
#  (('감동', 44), ('내용', 55)),
#  (('내용', 38), ('최악', 52)),
#  (('현실', 37), ('기대', 44)),
#  (('사랑', 36), ('생각', 44)),
#  (('배우', 36), ('연기', 38)),
#  (('마지막', 36), ('재미', 37)),
#  (('시간', 36), ('배우', 35)),
#  (('재미', 35), ('개연', 34)),
#  (('감독', 35), ('처음', 33)),
#  (('평점', 34), ('수준', 32)),
#  (('느낌', 33), ('이해', 28)),
#  (('마음', 31), ('마지막', 27)),
#  (('작품', 31), ('정도', 26)),
#  (('중간', 30), ('중간', 26)),
#  (('노래', 28), ('진짜', 26))]

# %%
ma.tagset
# Out:
# {'EC': '연결 어미',
#  'EF': '종결 어미',
#  'EP': '선어말어미',
#  'ETM': '관형형 전성 어미',
#  'ETN': '명사형 전성 어미',
#  'IC': '감탄사',
#  'JC': '접속 조사',
#  'JKB': '부사격 조사',
#  'JKC': '보격 조사',
#  'JKG': '관형격 조사',
#  'JKO': '목적격 조사',
#  'JKQ': '인용격 조사',
#  'JKS': '주격 조사',
#  'JKV': '호격 조사',
#  'JX': '보조사',
#  'MAG': '일반 부사',
#  'MAJ': '접속 부사',
#  'MM': '관형사',
#  'NA': '분석불능범주',
#  'NF': '명사추정범주',
#  'NNB': '의존 명사',
#  'NNG': '일반 명사',
#  'NNP': '고유 명사',
#  'NP': '대명사',
#  'NR': '수사',
#  'NV': '용언추정범주',
#  'SE': '줄임표',
#  'SF': '마침표, 물음표, 느낌표',
#  'SH': '한자',
#  'SL': '외국어',
#  'SN': '숫자',
#  'SO': '붙임표(물결,숨김,빠짐)',
#  'SP': '쉼표,가운뎃점,콜론,빗금',
#  'SS': '따옴표,괄호표,줄표',
#  'SW': '기타기호 (논리수학기호,화폐기호)',
#  'VA': '형용사',
#  'VCN': '부정 지정사',
#  'VCP': '긍정 지정사',
#  'VV': '동사',
#  'VX': '보조 용언',
#  'XPN': '체언 접두사',
#  'XR': '어근',
#  'XSA': '형용사 파생 접미사',
#  'XSN': '명사파생 접미사',
#  'XSV': '동사 파생 접미사'}

# %%
import matplotlib.pyplot as plt
from matplotlib import rc, font_manager

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/NanumGothic.ttf").get_name()

rc('font',family=font_name)

for pos, kor in ma.tagset.items():
    _pos = posPOS[pos].most_common()[:10]
    _neg = negPOS[pos].most_common()[:10]
    _posSum = sum([_[1] for _ in _pos])
    _negSum = sum([_[1] for _ in _neg])

    # x축 키값 y축 빈도 
    plt.bar(["+" + _[0] for _ in _pos], [_[1]/_posSum for _ in _pos])
    plt.bar(["-" + _[0] for _ in _neg], [_[1]/_negSum for _ in _neg])
    plt.title(kor)
    plt.xticks(rotation=45)
    plt.show()
